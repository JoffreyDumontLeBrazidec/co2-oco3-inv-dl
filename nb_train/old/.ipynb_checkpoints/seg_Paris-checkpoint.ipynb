# %% [markdown]
# ### Import lib

# %%
import os
os.chdir("/cerea_raid/users/dumontj/dev/coco2/dl")
import numpy as np
import sys
import pandas as pd
import xarray as xr
import tensorflow as tf
from tensorflow import keras
import keras.backend as K
import matplotlib.pyplot as plt
from treeconfigparser import TreeConfigParser

import models.seg as sm
from data.Data import Data

# %% [markdown]
# ### Loss functions

# %%
def pixel_weighted_cross_entropy(y_true, y_pred):    
    y_bin_true = tf.cast(y_true > 0, y_true.dtype)
    loss_val = keras.losses.binary_crossentropy(y_bin_true, y_pred)
    weights = tf.where(y_true > 0, y_true, 1.)
    loss_val = tf.convert_to_tensor(tf.squeeze(weights), np.float32)*loss_val
    return K.mean(loss_val)

# %% [markdown]
# ### Data generation

# %%
config_file = "nb/sim/cfg/seg_ber.cfg"
config = TreeConfigParser()
config.readfiles(config_file)
data = Data(config)
data.prepareXCO2Data()
# Out:
# x_train.shape[0] (6874, 160, 160, 1)
# y_train.shape (6874, 160, 160, 1)

# %% [markdown]
# ### Model def

# %%
model = sm.Unet_2(1, data.Ny, data.Nx, data.N_input_channels)
model.compile('adam', loss=pixel_weighted_cross_entropy)
#model.compile("adam", loss=tf.keras.losses.binary_crossentropy)
# Out:
# 2022-06-02 17:39:25.159006: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-02 17:39:25.588755: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21320 MB memory:  -> device: 0, name: Quadro RTX 6000, pci bus id: 0000:21:00.0, compute capability: 7.5

# %% [markdown]
# ### Training

# %%
model.fit(x=data.x_train, y=data.y_train, epochs=5, validation_data=(data.x_valid, data.y_valid))
# Out:
# Epoch 1/5
# 2022-06-02 17:39:28.996214: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8202
# 2022-06-02 17:39:29.392531: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 215/215 [==============================] - 18s 66ms/step - loss: 0.2929 - val_loss: 0.2594
# Epoch 2/5
# 215/215 [==============================] - 13s 59ms/step - loss: 0.2449 - val_loss: 0.2282
# Epoch 3/5
# 215/215 [==============================] - 13s 59ms/step - loss: 0.2189 - val_loss: 0.2098
# Epoch 4/5
# 215/215 [==============================] - 13s 59ms/step - loss: 0.2045 - val_loss: 0.1966
# Epoch 5/5
# 215/215 [==============================] - 13s 59ms/step - loss: 0.1952 - val_loss: 0.1839

# %% [markdown]
# ### Evaluation

# %%
idx = int(np.random.uniform(0,data.N_valid*0.2))

plt.figure()
plt.imshow(np.squeeze(data.trace_valid[idx]))
plt.colorbar()
plt.title("trace")

plt.figure()
plt.imshow(np.squeeze(data.y_valid[idx]))
plt.colorbar()
plt.title("truth")

plt.figure()
plt.imshow(np.squeeze(model(tf.expand_dims(data.x_valid[0][idx], 0))[0]))
plt.colorbar()
plt.title("pred")

plt.figure()
plt.imshow(np.squeeze(data.x_valid[0][idx]))
plt.colorbar()
plt.title("image")
# Out:
# Text(0.5, 1.0, 'image')
