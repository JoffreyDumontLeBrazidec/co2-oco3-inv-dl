# %%
import os
import numpy as np
import sys
import pandas as pd
import xarray as xr
import tensorflow as tf
from tensorflow import keras
import keras.backend as K
import joblib
import pickle
from treeconfigparser import TreeConfigParser

import matplotlib.pyplot as plt
import seaborn as sns
from functools import partial
from matplotlib import colors
from matplotlib import ticker
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader
from cmcrameri import cm
import matplotlib_functions
matplotlib_functions.setMatplotlibParam()
plt.viridis()

os.chdir("/cerea_raid/users/dumontj/dev/coco2/dl")
from include.loss import pixel_weighted_cross_entropy
import dplume
import ddeq

import build_ds
import ddeq_pred
import ddeq_eval

from scipy.optimize import differential_evolution

# %%
dir_eval_ddeq = "/libre/dumontj/coco2/ddeq/eval"
Ny = 160
Nx = 160

# %%
PS = "Berlin"
ds = xr.open_dataset(os.path.join(dir_eval_ddeq, 
                                  build_ds.get_abbrev_source(PS),
                                  "res_ddeq.nc"))

# %%
y_test = tf.convert_to_tensor(np.expand_dims(ds.plume.values, -1), np.float32) 
pred_test = tf.convert_to_tensor(np.expand_dims(ds.ddeq_plumes.values, -1), np.float32)
# Out:
# 2022-10-07 16:56:11.526416: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-07 16:56:11.971659: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14688 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:65:00.0, compute capability: 7.5

# %% [markdown]
# ### Score with baseline

# %%
pred_test = 0.1*tf.ones(shape=y_test.shape)
all_loss_test = pixel_weighted_cross_entropy(y_test, pred_test, reduction=False)
all_loss_test = np.mean(all_loss_test,axis=(1,2))

# %%
all_means_losses = np.empty((proba_max_range.shape[0], proba_min_range.shape[0]))
for i, proba_max in enumerate(proba_max_range):
    for j, proba_min in enumerate(proba_min_range):
        current_pred_test = shift_to_proba(pred_test,proba_max,proba_min)
        current_pred_test = tf.convert_to_tensor(current_pred_test, np.float32)
        
        all_loss_test = pixel_weighted_cross_entropy(y_test, current_pred_test, reduction=False)
        all_loss_test = np.mean(np.mean(all_loss_test,axis=(1,2)))
        #print (i,j,proba_max, proba_min, all_loss_test)
        all_means_losses[i,j] = all_loss_test

# %%
n_outliers_val = int(0.01*len(all_loss_test))
indices_with_no_outliers = np.argpartition(all_loss_test, -n_outliers_val)[:-n_outliers_val]
indices_outliers = np.argpartition(all_loss_test, -n_outliers_val)[-n_outliers_val:]

# %% [markdown]
# ### evaluate best proba max best proba min on a validation dataset, and evaluate it on a test dataset

# %%
all_loss_test = pixel_weighted_cross_entropy(y_test, pred_test, reduction=False)
all_loss_test = np.mean(all_loss_test,axis=(1,2))
print("mean loss:", np.mean(all_loss_test))
print("median loss:", np.median(all_loss_test))

# %%
proba_max_range = np.arange(0.9, 1.0, 0.01)
proba_min_range = np.arange(0.0, 0.1, 0.01)

# %%
proba_max_range

# %%
means_losses = np.empty(
for proba_max in proba_max_range:
    for proba_min in proba_min_range:
        current_pred_test = shift_to_proba(pred_test,proba_max,proba_min)
        current_pred_test = tf.convert_to_tensor(current_pred_test, np.float32)
        
        all_loss_test = pixel_weighted_cross_entropy(y_test, current_pred_test, reduction=False)
        all_loss_test = np.mean(all_loss_test,axis=(1,2))
        print("proba_min", proba_min, "proba_max", proba_max)
        print("mean loss:", np.mean(all_loss_test))
        print("median loss:", np.median(all_loss_test))
        print("__")

# %%
best_proba_max, best_proba_min =

# %%
axs = matplotlib_functions.set_figure_axs(1,2, pad_w_ext_left=0.1, pad_w_ext_right=0.1, 
                                          pad_w_int=0.15, pad_h_ext=0.2, pad_h_int=0.15)
axs[0].imshow(ds_sub.xco2[0])
axs[1].imshow(ds_sub.ddeq_plumes[0])

# %%
Ny = ds.dims["y"]
Nx = ds.dims["x"]
y_test = tf.convert_to_tensor(ds_sub["weight_bool_plume"].values.reshape(N_tests, Ny, Nx, 1), np.float32) 
pred_test = tf.convert_to_tensor(ds_sub["ddeq_plumes"].values.reshape(N_tests, Ny, Nx, 1), np.float32) 

all_loss_test = pixel_weighted_cross_entropy(y_test, pred_test, reduction=False)
all_loss_test = np.mean(all_loss_test,axis=(1,2))
print("mean loss:", np.mean(all_loss_test))
print("median loss:", np.median(all_loss_test))
# Out:
# mean loss: 2.600593
# median loss: 2.3755631
# 2022-10-06 18:53:14.752914: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-06 18:53:15.241670: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14688 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:65:00.0, compute capability: 7.5

# %%
proba_max_range = np.arange(0.9, 1.0, 0.01)
proba_min_range = np.arange(0.0, 0.1, 0.01)

# %%
all_means_losses = np.empty((proba_max_range.shape[0], proba_min_range.shape[0]))
for i, proba_max in enumerate(proba_max_range):
    for j, proba_min in enumerate(proba_min_range):
        current_pred_test = shift_to_proba(pred_test,proba_max,proba_min)
        current_pred_test = tf.convert_to_tensor(current_pred_test, np.float32)
        
        all_loss_test = pixel_weighted_cross_entropy(y_test, current_pred_test, reduction=False)
        all_loss_test = np.mean(np.mean(all_loss_test,axis=(1,2)))
        #print (i,j,proba_max, proba_min, all_loss_test)
        all_means_losses[i,j] = all_loss_test

# %%
print(np.min(all_means_losses))
# Out:
# 0.491578608751297

# %%
t = np.random.choice(100,1)[0]

# %%
axs = matplotlib_functions.set_figure_axs(1,2, pad_w_ext_left=0.1, pad_w_ext_right=0.1, 
                                         pad_w_int=0.15, pad_h_ext=0.2, pad_h_int=0.15)
current_pred_test = shift_to_proba(pred_test[t:t+1], 0.9, 0.1)
current_pred_test = tf.convert_to_tensor(current_pred_test, np.float32)
all_loss_test = pixel_weighted_cross_entropy(y_test[t:t+1], current_pred_test, reduction=False)
print(np.mean(all_loss_test))

im0 = axs[0].imshow(y_test[t,:,:,0])
cax0 = axs[0].inset_axes((1.02, 0, 0.035, 1))
cbar0 = plt.colorbar(im0, cax0, orientation="vertical")
im1 = axs[1].imshow(current_pred_test[0,:,:,0])
cax1 = axs[1].inset_axes((1.02, 0, 0.035, 1))
cbar1 = plt.colorbar(im1, cax1, orientation="vertical")
# Out:
# 0.1319479

# %%
current_pred_test = tf.zeros(shape=(1,160,160))

all_loss_test = pixel_weighted_cross_entropy(y_test[t:t+1], current_pred_test, reduction=False)
print(np.mean(all_loss_test, axis=(1,2)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 current_pred_test = tf.zeros(shape=(1,160,160))
#       3 all_loss_test = pixel_weighted_cross_entropy(y_test[t:t+1], current_pred_test, reduction=False)
#       4 print(np.mean(all_loss_test, axis=(1,2)))
#
# NameError: name 'tf' is not defined

# %%
t = np.random.choice(100,1)[0]
axs = matplotlib_functions.set_figure_axs(1,2, pad_w_ext_left=0.1, pad_w_ext_right=0.1, 
                                         pad_w_int=0.15, pad_h_ext=0.2, pad_h_int=0.15)
axs[0].imshow(ds_sub.xco2[t])
axs[1].imshow(ds_sub.ddeq_plumes[t])

# %%
y_test = tf.convert_to_tensor(np.expand_dims(ds.weight_bool_plume.values, -1), np.float32) 
pred_test = tf.convert_to_tensor(np.expand_dims(ds.ddeq_plumes.values, -1), np.float32) 
#pred_test = 0.1*tf.ones(shape=y.shape)£
res = differential_evolution(ddeq_eval.get_mean_loss, args=(y_test, pred_test), bounds = [[0,1], [0,1]])
#[proba_min, proba_max] = res["x"]
#loss_mean = res["fun"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <module>
#       3 #pred_test = 0.1*tf.ones(shape=y.shape)£
#       4 import ddeq_eval
# ----> 5 res = differential_evolution(ddeq_eval.get_mean_loss, args=(y_test, pred_test), bounds = [[0,1], [0,1]])
#
# File /cerea_raid/users/dumontj/usr/anaconda3/envs/tf-gpu/lib/python3.8/site-packages/scipy/optimize/_differentialevolution.py:308, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints)
#     294 # using a context manager means that any created Pool objects are
#     295 # cleared up.
#     296 with DifferentialEvolutionSolver(func, bounds, args=args,
#     297                                  strategy=strategy,
#     298                                  maxiter=maxiter,
#    (...)
# ...

# %%
loss_mean
# Out:
#      fun: 0.4683056175708771
#  message: 'Optimization terminated successfully.'
#     nfev: 243
#      nit: 5
#  success: True
#        x: array([0.16250332, 0.88577441])
